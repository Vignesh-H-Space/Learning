# %% [markdown]
# # Salary Prediction using Linear Regression

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Importing Dataset

# %%
salary_data = pd.read_csv("Salary_dataset.csv")

# %%
print(salary_data)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %% [markdown]
# ## Perform Initial Investigation on Data

# %%
salary_data.shape
# Out:
# (30, 3)

# %%
salary_data.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
salary_data.dtypes
# Out:
# Unnamed: 0           int64
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
salary_data.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %% [markdown]
# ## Checking for Assumptions

# %% [markdown]
# ### Test 1 : Linearity Test

# %%
sns.lmplot(data= salary_data, x = "Salary", y = "YearsExperience")

# %% [markdown]
# ### Linearity Test Passed

# %% [markdown]
# ### Test 2 : Normality Test

# %%
plt.hist(x = "Salary", data = salary_data)
# Out:
# (array([4., 2., 7., 4., 0., 2., 2., 2., 4., 3.]),
#  array([ 37732.,  46198.,  54664.,  63130.,  71596.,  80062.,  88528.,
#          96994., 105460., 113926., 122392.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = "YearsExperience", data = salary_data)
# Out:
# (array([4., 2., 5., 4., 3., 2., 2., 2., 3., 3.]),
#  array([ 1.2 ,  2.14,  3.08,  4.02,  4.96,  5.9 ,  6.84,  7.78,  8.72,
#          9.66, 10.6 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Normality Test Failed

# %% [markdown]
# ### Test 3 - Multicollinearity test

# %%
corr_matrix = salary_data.corr()

# %%
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### There is multicollinearity in the data

# %% [markdown]
# ## 4. Data Preparation

# %%
salary_data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %% [markdown]
# ### There is nothing to prepare since because all features are numeric.

# %% [markdown]
# ### Input Segregation

# %%
X = salary_data[["YearsExperience"]]

# %%
X
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y = salary_data["Salary"]

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## 5. Model Building

# %%
linear_model = LinearRegression()

# %% [markdown]
# ## 6. Model Training

# %%
linear_model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Intercept - Where the line meets at the y - axis

# %%
linear_model.intercept_
# Out:
# np.float64(24848.203966523208)

# %%
# Slope

# %%
linear_model.coef_
# Out:
# array([9449.96232146])

# %% [markdown]
# ### Test 5 - Homoscedascity Test

# %%
plt.scatter(data= salary_data, x = "Salary", y = "YearsExperience")

# %% [markdown]
# ### Test 5 - Homoscedascity Test Passed
