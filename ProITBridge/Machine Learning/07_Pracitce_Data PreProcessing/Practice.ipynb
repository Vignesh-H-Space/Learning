# %%
# Importing Dataset

# %%
import pandas as pd

# %%
fi = pd.read_csv("Phase 1 - CEN 07.csv")

# %%
fi.dtypes
# Out:
# Q.No        int64
# Answers    object
# dtype: object

# %%
co = fi["Answers"].value_counts()

# %%
print(co)
# Out:
# Answers
# C    57
# N    25
# W    18
# Name: count, dtype: int64
