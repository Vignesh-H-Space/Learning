# %% [markdown]
# # DATA PREPROCESSING / DATA PREPARATION

# %% [markdown]
# ##### 1. Data Cleaning - drop, fillna with mean, median, mode imputation, changing dtype
# ##### 2. Data Transformation
# #####       If data is CONTINUOUS - Standard Scaler, MinMaxScaler, Robust Scaler
# #####       If data is discrete - Label Encoder, One hot Encoder

# %% [markdown]
# ## 1. Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Import Dataset

# %%
env_data = pd.read_csv("environmental_data.csv")
env_data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# ## 3. Data Understanding

# %%
# Perform Initial Analysis

# %%
env_data.shape
# Out:
# (158, 10)

# %%
env_data.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
env_data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
env_data.describe(include='all')
# Out:
#         Unnamed: 0       Ozone     Solar.R        Wind Temp C Month  \
# count   158.000000  120.000000  151.000000  158.000000    158   158
# unique         NaN         NaN         NaN         NaN     41     6
# top            NaN         NaN         NaN         NaN     81     9
# freq           NaN         NaN         NaN         NaN     11    34
# mean     79.500000   41.583333  185.403974    9.957595    NaN   NaN
# std      45.754781   32.620709   88.723103    3.511261    NaN   NaN
# min       1.000000    1.000000    7.000000    1.700000    NaN   NaN
# 25%      40.250000   18.000000  119.000000    7.400000    NaN   NaN
# 50%      79.500000   30.500000  197.000000    9.700000    NaN   NaN
# 75%     118.750000   61.500000  257.000000   11.875000    NaN   NaN
# max     158.000000  168.000000  334.000000   20.700000    NaN   NaN
#
#                Day    Year        Temp Weather
# count   158.000000   158.0  158.000000     155
# unique         NaN     NaN         NaN       3
# ...

# %%
env_data["Weather"].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %%
env_data["Weather"].value_counts(dropna=False)
# Out:
# Weather
# S      59
# C      49
# PS     47
# NaN     3
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Data Preparation

# %%
## Stage 1 - Data Cleaning - dropna, fillna with mean, median, mode Imputation, changing dtype

# %%
env_data.head(10)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5           6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6           7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7           8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8           9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9          10    NaN    194.0   8.6     69     5   10  2010    69       S

# %%
env_data.drop(labels = ["Unnamed: 0","Temp C"],axis = 1,inplace=True)
env_data
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
env_data.isna().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
env_data.shape
# Out:
# (158, 8)

# %%
38/158
# Out:
# 0.24050632911392406

# %%
# So, there is 38 NaN values in Ozone row out of entire 158 rows

# %%
# Removing the entire row of Ozone

# %%
del env_data["Ozone"]

# %%
env_data.isna().sum()
# Out:
# Solar.R    7
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
# Finding Null entries present in Solar.R Data row

# %%
env_data[env_data["Solar.R"].isna()]
# Out:
#     Solar.R  Wind Month  Day  Year  Temp Weather
# 4       NaN  14.3     5    5  2010    56       S
# 5       NaN  14.9     5    6  2010    66       C
# 10      NaN   6.9     5   11  2010    74       C
# 26      NaN   8.0     5   27  2010    57      PS
# 95      NaN   6.9     8    4  2010    86     NaN
# 96      NaN   7.4     8    5  2010    85       S
# 97      NaN   4.6     8    6  2010    87       C

# %%
env_data.groupby("Weather")["Solar.R"].mean().round()
# Out:
# Weather
# C     192.0
# PS    174.0
# S     193.0
# Name: Solar.R, dtype: float64

# %%
env_data["Solar.R"] = env_data.groupby("Weather")["Solar.R"].transform(lambda x:x.fillna(x.mean().round()))

# %%
env_data
# Out:
#      Solar.R  Wind Month  Day  Year  Temp Weather
# 0      190.0   7.4     5    1  2010    67       S
# 1      118.0   8.0     5    2  2010    72       C
# 2      149.0  12.6     5    3  2010    74      PS
# 3      313.0  11.5     5    4  2010    62       S
# 4      193.0  14.3     5    5  2010    56       S
# ..       ...   ...   ...  ...   ...   ...     ...
# 153    190.0   7.4     5    1  2010    67       C
# 154    193.0   6.9     9   26  2010    70      PS
# 155    145.0  13.2     9   27  2010    77       S
# 156    191.0  14.3     9   28  2010    75       S
# 157    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 7 columns]

# %%
env_data.isna().sum()
# Out:
# Solar.R    3
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
env_data[env_data["Solar.R"].isna()]
# Out:
#     Solar.R  Wind Month  Day  Year  Temp Weather
# 87      NaN  12.0     7   27  2010    86     NaN
# 93      NaN  13.8     8    2  2010    81     NaN
# 95      NaN   6.9     8    4  2010    86     NaN

# %%
env_data.dropna(inplace=True)
env_data
# Out:
#      Solar.R  Wind Month  Day  Year  Temp Weather
# 0      190.0   7.4     5    1  2010    67       S
# 1      118.0   8.0     5    2  2010    72       C
# 2      149.0  12.6     5    3  2010    74      PS
# 3      313.0  11.5     5    4  2010    62       S
# 4      193.0  14.3     5    5  2010    56       S
# ..       ...   ...   ...  ...   ...   ...     ...
# 153    190.0   7.4     5    1  2010    67       C
# 154    193.0   6.9     9   26  2010    70      PS
# 155    145.0  13.2     9   27  2010    77       S
# 156    191.0  14.3     9   28  2010    75       S
# 157    131.0   8.0     9   29  2010    76       C
#
# [155 rows x 7 columns]

# %%
env_data.isna().sum()
# Out:
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
env_data.dtypes
# Out:
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
env_data["Month"].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
env_data.head(15)
# Out:
#     Solar.R  Wind Month  Day  Year  Temp Weather
# 0     190.0   7.4     5    1  2010    67       S
# 1     118.0   8.0     5    2  2010    72       C
# 2     149.0  12.6     5    3  2010    74      PS
# 3     313.0  11.5     5    4  2010    62       S
# 4     193.0  14.3     5    5  2010    56       S
# 5     192.0  14.9     5    6  2010    66       C
# 6     299.0   8.6     5    7  2010    65      PS
# 7      99.0  13.8     5    8  2010    59       C
# 8      19.0  20.1     5    9  2010    61      PS
# 9     194.0   8.6     5   10  2010    69       S
# 10    192.0   6.9     5   11  2010    74       C
# 11    256.0   9.7     5   12  2010    69      PS
# 12    290.0   9.2     5   13  2010    66       S
# 13    274.0  10.9     5   14  2010    68       S
# 14     65.0  13.2     5   15  2010    58       C

# %%
env_data["Month"].replace(to_replace="May",value=5,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2464\2075127343.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   env_data["Month"].replace(to_replace="May",value=5,inplace=True)

# %%
env_data["Month"].unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
env_data.head(30)
# Out:
#     Solar.R  Wind Month  Day  Year  Temp Weather
# 0     190.0   7.4     5    1  2010    67       S
# 1     118.0   8.0     5    2  2010    72       C
# 2     149.0  12.6     5    3  2010    74      PS
# 3     313.0  11.5     5    4  2010    62       S
# 4     193.0  14.3     5    5  2010    56       S
# 5     192.0  14.9     5    6  2010    66       C
# 6     299.0   8.6     5    7  2010    65      PS
# 7      99.0  13.8     5    8  2010    59       C
# 8      19.0  20.1     5    9  2010    61      PS
# 9     194.0   8.6     5   10  2010    69       S
# 10    192.0   6.9     5   11  2010    74       C
# 11    256.0   9.7     5   12  2010    69      PS
# 12    290.0   9.2     5   13  2010    66       S
# 13    274.0  10.9     5   14  2010    68       S
# 14     65.0  13.2     5   15  2010    58       C
# 15    334.0  11.5     5   16  2010    64       S
# 16    307.0  12.0     5   17  2010    66       S
# 17     78.0  18.4     5   18  2010    57       C
# ...
