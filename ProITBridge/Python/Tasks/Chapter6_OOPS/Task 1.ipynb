# %% [markdown]
# # Task 1

# %% [markdown]
# ## Abstraction , Inheritance & Polymorphism

# %% [markdown]
# ### First creating normal class with objects

# %%
class Player :
    def __init__(self,name:str,country:str):
        self.name = name
        self.country = country 

    def guess_player_name (self, guess):
        return guess.lower() == self.name.lower()

    def get_country(self):
        return self.country

# %% [markdown]
# #### Object Creation

# %%
player1 = Player("Ronaldo","Portugal")

# %%
player1.get_name("Messi")
# Out:
# False

# %%
player1.get_name("Ronaldo")
# Out:
# True

# %%
player1.get_country()
# Out:
# 'Portugal'
