# %% [markdown]
# # User Defined Module Creation

# %%
def addition (a ,b):
    return a + b

# %%
def subtraction (a,b):
    return a - b

# %%
def multiplication(a,b):
    return a * b

# %%
def division (a,b):
    return a / b
