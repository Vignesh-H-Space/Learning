# %% [markdown]
# # Advanced Data Analysis

# %% [markdown]
# ## Group by function

# %%
import pandas as pd

# %%
insurance_data = pd.read_csv("insurance.csv")

# %%
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Perform Initial Analysis

# %%
insurance_data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance_data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance_data["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [markdown]
# ### Pull Up average Insurance Charges by region

# %% [markdown]
# #### Discrete and Continuous Data

# %% [markdown]
# ##### Discrete - Just Continous / Can't be segmented
# ##### Continuous - Measurable / Have units / Can be segmented

# %%
# In insurance data 
# Discrete - Sex, Children, Smoker, Region
# Continuous - Age, BMI, Charges

# %%
# Here, in groupby function - by should have discrete first and then followed by continuous

# %%
insurance_data.groupby(by="region")["charges"].mean().round(2).sort_values()
# Out:
# region
# southwest    12346.94
# northwest    12417.58
# northeast    13406.38
# southeast    14735.41
# Name: charges, dtype: float64

# %%
### Pull Up average Insurance Charges by region and Sex

# %%
insurance_data.groupby(by=["region","sex"])["charges"].mean().round(2).sort_values()
# Out:
# region     sex
# southwest  female    11274.41
# northwest  male      12354.12
#            female    12479.87
# northeast  female    12953.20
# southwest  male      13412.88
# southeast  female    13499.67
# northeast  male      13854.01
# southeast  male      15879.62
# Name: charges, dtype: float64

# %% [markdown]
# ### Pivot Table

# %%
pd.pivot_table( data= insurance_data, values= "charges", index="region", columns="sex").round(2)
# Out:
# sex          female      male
# region
# northeast  12953.20  13854.01
# northwest  12479.87  12354.12
# southeast  13499.67  15879.62
# southwest  11274.41  13412.88

# %%
pd.pivot_table( data= insurance_data, values= "charges", index="region", columns=["sex","children","smoker"]).round(2)   # More than one Category
# Out:
# sex         female                                                    \
# children         0                   1                   2
# smoker          no       yes        no       yes        no       yes
# region
# northeast  8169.64  24834.34  10920.69  31083.68  11937.80  24864.90
# northwest  7560.08  28837.31   8196.13  32308.59  10659.31  29788.51
# southeast  7746.72  36207.88   7893.36  23376.32   6922.90  34046.01
# southwest  7221.16  27428.38   8575.39  38036.63   9951.18  36861.55
#
# sex                                               ...      male           \
# children          3                   4        5  ...         0        1
# smoker           no       yes        no       no  ...       yes       no
# region                                            ...
# northeast   8962.80  29223.84  14542.42      NaN  ...  29394.86  8912.30
# northwest  10187.45  30457.81  11024.42  8965.80  ...  27109.42  7808.83
# southeast  13683.15  31802.65  18267.10  9923.89  ...  34889.05  8174.22
# southwest   8438.74       NaN  10945.68  7023.78  ...  33134.03  6664.47
#
# sex                                                                    \
# children                    2                   3                   4
# smoker          yes        no       yes        no       yes        no
# region
# northeast  33847.86  11311.29  18357.64   6589.45  37190.63  14442.28
# northwest  21799.78   9267.69  31741.99  11178.72  38694.56   8186.93
# southeast  35925.52   8068.38  38993.29  10290.07  33450.01   8726.91
# southwest  32457.95   7588.34  38064.90   8889.83  21616.88   6785.72
#
# sex
# children                    5
# smoker          yes        no
# region
# northeast       NaN   6978.97
# northwest  21472.48       NaN
# southeast       NaN  10306.99
# southwest  29062.18   6864.67
#
# [4 rows x 22 columns]

# %% [markdown]
# ### Aggregate

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.groupby(by="region")["charges"].mean().round(2).sort_values()
# Out:
# region
# southwest    12346.94
# northwest    12417.58
# northeast    13406.38
# southeast    14735.41
# Name: charges, dtype: float64

# %%
# Using aggregation to find multiple properties

# %%
insurance_data.groupby(by="region")["charges"].agg(func = ["mean","max","min","sum"]).round(2)
# Out:
#                mean       max      min         sum
# region
# northeast  13406.38  58571.07  1694.80  4343668.58
# northwest  12417.58  60021.40  1621.34  4035712.00
# southeast  14735.41  63770.43  1121.87  5363689.76
# southwest  12346.94  52590.83  1241.56  4012754.65

# %%
insurance_data.groupby(by=["region","sex"])["charges"].agg(func = ["mean","max","min","sum"]).round(2)
# Out:
#                       mean       max      min         sum
# region    sex
# northeast female  12953.20  58571.07  2196.47  2085465.71
#           male    13854.01  48549.18  1694.80  2258202.88
# northwest female  12479.87  55135.40  2117.34  2046698.75
#           male    12354.12  60021.40  1621.34  1989013.25
# southeast female  13499.67  63770.43  1607.51  2362442.12
#           male    15879.62  62592.87  1121.87  3001247.65
# southwest female  11274.41  48824.45  1727.78  1826454.62
#           male    13412.88  52590.83  1241.56  2186300.02

# %% [markdown]
# ### Cross Tab

# %% [markdown]
# #### Find out total number of smokers and non smokers in each region

# %%
pd.crosstab(index= insurance_data["smoker"],columns = insurance_data["region"],margins = True)
# Out:
# region  northeast  northwest  southeast  southwest   All
# smoker
# no            257        267        273        267  1064
# yes            67         58         91         58   274
# All           324        325        364        325  1338

# %% [markdown]
# ### Concat

# %%
sales_data_2017 = pd.read_csv("Sales-Transactions-2017.csv")
sales_data_2018 = pd.read_csv("Sales-Transactions-2018.csv")
sales_data_2019 = pd.read_csv("Sales-Transactions-2019.csv")

# %%
sales_data_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# 0                 2      1,690.00        3,380.00         NaN       13,100.00
# 1                 6      1,620.00        9,720.00         NaN             NaN
# 2               500            23       11,500.00         NaN       30,990.00
# 3                 6      1,620.00        9,720.00         NaN             NaN
# 4                 5      1,690.00        8,450.00         NaN             NaN
# ...             ...           ...             ...         ...             ...
# 47285            25           137        3,425.00         NaN        3,425.00
# 47286           NaN           NaN             NaN         NaN             NaN
# 47287           NaN           NaN             NaN         NaN             NaN
# 47288    607,734.60    669,300.49    9,953,816.13  106,607.00    9,868,583.13
# 47289  7,593,062.00  8,309,116.00  115,778,725.71  936,348.00  115,105,123.71
#
# [47290 rows x 9 columns]

# %%
sales_data_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# 0                 85        4,250.00         NaN       66,724.00
# 1                290        1,450.00         NaN             NaN
# 2                5.5        8,800.00         NaN             NaN
# 3                 11        4,400.00         NaN             NaN
# 4                8.1        4,860.00         NaN             NaN
# ...              ...             ...         ...             ...
# 44735             40        8,000.00         NaN             NaN
# 44736            NaN             NaN         NaN             NaN
# 44737            NaN             NaN         NaN             NaN
# 44738   1,067,808.80   10,796,991.30   29,999.00   10,787,647.30
# 44739  10,024,197.00  117,897,671.80  720,204.00  117,427,983.80
#
# [44740 rows x 9 columns]

# %%
sales_data_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# 0          1,730.00       1,730.00         NaN       3,460.00
# 1          1,730.00       1,730.00         NaN            NaN
# 2              18.5       2,035.00         NaN       2,035.00
# 3                 0
# 4               585       1,755.00         NaN       1,755.00
# ...             ...            ...         ...            ...
# 19171            16       6,400.00         NaN            NaN
# 19172           NaN            NaN         NaN            NaN
# 19173           NaN            NaN         NaN            NaN
# 19174    175,381.65   2,203,649.50   20,680.00   2,189,014.50
# 19175  5,519,888.40  53,360,791.40  672,984.00  52,830,224.40
#
# [19176 rows x 9 columns]

# %%
sales_final_data = pd.concat(objs = [sales_data_2017, sales_data_2018, sales_data_2019])
sales_final_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# 1                 6      1,620.00       9,720.00         NaN            NaN
# 2               500            23      11,500.00         NaN      30,990.00
# 3                 6      1,620.00       9,720.00         NaN            NaN
# 4                 5      1,690.00       8,450.00         NaN            NaN
# ...             ...           ...            ...         ...            ...
# 19171           400            16       6,400.00         NaN            NaN
# 19172           NaN           NaN            NaN         NaN            NaN
# 19173           NaN           NaN            NaN         NaN            NaN
# 19174     99,284.90    175,381.65   2,203,649.50   20,680.00   2,189,014.50
# 19175  2,710,193.00  5,519,888.40  53,360,791.40  672,984.00  52,830,224.40
#
# [111206 rows x 9 columns]
