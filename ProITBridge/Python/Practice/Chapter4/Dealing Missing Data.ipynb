# %% [markdown]
# # Dealing with Missing Data

# %%
import pandas as pd

# %%
data = pd.read_csv("employee_data.csv")

# %%
data1 = pd.read_csv("employee_data.csv")

# %%
print(data)
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %%
# Some NaN values are present in the data

# %% [markdown]
# ### Removing Duplicates

# %%
data = data.drop_duplicates()

# %%
print(data)
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %% [markdown]
# #### Inplace Argument - Alters the original Dataset

# %%
print(data1)
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %%
data1.drop_duplicates(inplace = True)

# %%
print(data1)
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %% [markdown]
# #### Finding Null Entries

# %%
data1.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %% [markdown]
# #### Removing Null data

# %% [markdown]
# ##### Noting the shape before Deletion

# %%
data1.shape
# Out:
# (7, 5)

# %%
data1.dropna(inplace=True)

# %%
data1
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %% [markdown]
# ##### Noting the shape after Deletion

# %%
data1.shape
# Out:
# (4, 5)

# %% [markdown]
# #### Result

# %% [markdown]
# ##### There were 7 observations and 3 observations were removed since the were incomplete

# %%
data1.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# ## For Excel

# %%
pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/250.9 kB 640.0 kB/s eta 0:00:01
#      ---- -------------------------------- 30.7/250.9 kB 640.0 kB/s eta 0:00:01
#      --------- --------------------------- 61.4/250.9 kB 409.6 kB/s eta 0:00:01
#      ------------- ----------------------- 92.2/250.9 kB 581.0 kB/s eta 0:00:01
#      ------------- ----------------------- 92.2/250.9 kB 581.0 kB/s eta 0:00:01
#      -------------- --------------------- 102.4/250.9 kB 392.2 kB/s eta 0:00:01
#      ------------------------ ----------- 174.1/250.9 kB 551.6 kB/s eta 0:00:01
#      -------------------------------- --- 225.3/250.9 kB 625.1 kB/s eta 0:00:01
#      ------------------------------------ 250.9/250.9 kB 641.8 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# ...

# %%
value = pd.read_excel("employee_data.xlsx")

# %%
value
# Out:
#       Name   Age Department   Salary  Join_Date
# 0   Rajesh  29.0        Ops  60000.0 2023-05-21
# 1    Nasir  31.0    IT Tech      NaN 2020-11-12
# 2  Mathiew   NaN    Support  58000.0 2025-01-15
# 3  Gilbert  29.0        Ops  60000.0 2021-05-21
# 4    Kevin  28.0    Support  61000.0 2024-07-30
# 5    Navin  35.0    Support  72000.0 2023-08-19
# 6      NaN  40.0         IT  64000.0 2022-09-10
# 7    Nasir  31.0    IT Tech      NaN 2020-11-12

# %% [markdown]
# ### To get the data of other sheets in excel

# %%
value = pd.read_excel("employee_data.xlsx",sheet_name = "Extended Data")

# %%
print(value)
# Out:
#        Name   Age Department   Salary  Join_Date
# 0    Ramesh  29.0        Ops  60000.0 2023-05-21
# 1     Nasir  31.0    IT Tech      NaN 2020-11-12
# 2   Mathiew   NaN    Support  58000.0 2025-01-15
# 3   Gilbert  29.0        Ops  60000.0 2021-05-21
# 4     Kevin  28.0    Support  61000.0 2024-07-30
# 5     Navin  35.0    Support  72000.0 2023-08-19
# 6       NaN  40.0         IT  64000.0 2022-09-10
# 7     Nasir  31.0    IT Tech      NaN 2020-11-12
# 8      Maha  24.0    Support  23000.0 2023-01-15
# 9    Anjali  43.0        Ops  75000.0        NaT
# 10    Priya  35.0         IT  50000.0 2023-08-19
# 11  Kluvert  29.0        NaN  79000.0 2021-05-21
# 12  Gilbert  29.0        Ops  60000.0 2021-05-21
# 13   Ramesh  29.0        Ops  60000.0 2023-05-21

# %%
value.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# dtype: bool

# %%
value.drop_duplicates(inplace = True)

# %%
print(value)
# Out:
#        Name   Age Department   Salary  Join_Date
# 0    Ramesh  29.0        Ops  60000.0 2023-05-21
# 1     Nasir  31.0    IT Tech      NaN 2020-11-12
# 2   Mathiew   NaN    Support  58000.0 2025-01-15
# 3   Gilbert  29.0        Ops  60000.0 2021-05-21
# 4     Kevin  28.0    Support  61000.0 2024-07-30
# 5     Navin  35.0    Support  72000.0 2023-08-19
# 6       NaN  40.0         IT  64000.0 2022-09-10
# 8      Maha  24.0    Support  23000.0 2023-01-15
# 9    Anjali  43.0        Ops  75000.0        NaT
# 10    Priya  35.0         IT  50000.0 2023-08-19
# 11  Kluvert  29.0        NaN  79000.0 2021-05-21

# %% [markdown]
# ## Identify Null Entries

# %%
value.isna()
# Out:
#      Name    Age  Department  Salary  Join_Date
# 0   False  False       False   False      False
# 1   False  False       False    True      False
# 2   False   True       False   False      False
# 3   False  False       False   False      False
# 4   False  False       False   False      False
# 5   False  False       False   False      False
# 6    True  False       False   False      False
# 8   False  False       False   False      False
# 9   False  False       False   False       True
# 10  False  False       False   False      False
# 11  False  False        True   False      False

# %%
value.isna().sum()
# Out:
# Name          1
# Age           1
# Department    1
# Salary        1
# Join_Date     1
# dtype: int64

# %% [markdown]
# #### Identifying different Departments

# %% [markdown]
# ##### Ops Department

# %%
value[value["Department"] == "Ops"]
# Out:
#       Name   Age Department   Salary  Join_Date
# 0   Ramesh  29.0        Ops  60000.0 2023-05-21
# 3  Gilbert  29.0        Ops  60000.0 2021-05-21
# 9   Anjali  43.0        Ops  75000.0        NaT

# %% [markdown]
# ##### IT Tech Department

# %%
value[value["Department"] == "IT Tech"]
# Out:
#     Name   Age Department  Salary  Join_Date
# 1  Nasir  31.0    IT Tech     NaN 2020-11-12

# %% [markdown]
# ##### Support Department

# %%
value[value["Department"] == "Support"]
# Out:
#       Name   Age Department   Salary  Join_Date
# 2  Mathiew   NaN    Support  58000.0 2025-01-15
# 4    Kevin  28.0    Support  61000.0 2024-07-30
# 5    Navin  35.0    Support  72000.0 2023-08-19
# 8     Maha  24.0    Support  23000.0 2023-01-15

# %% [markdown]
# ##### IT Department

# %%
value[value["Department"] == "IT"]
# Out:
#      Name   Age Department   Salary  Join_Date
# 6     NaN  40.0         IT  64000.0 2022-09-10
# 10  Priya  35.0         IT  50000.0 2023-08-19

# %% [markdown]
# ### Task

# %% [markdown]
# #### Impute Data at NaN places

# %%
value[value["Salary"].isna()]
# Out:
#     Name   Age Department  Salary  Join_Date
# 1  Nasir  31.0    IT Tech     NaN 2020-11-12
